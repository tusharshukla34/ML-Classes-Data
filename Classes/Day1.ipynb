# %% [markdown]
# Importing Library

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
import random

# %%
from sklearn.impute import SimpleImputer
